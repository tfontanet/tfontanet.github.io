# %% [markdown]
# # Les fonctions récursives : Activité de découverte
#
# ---
# !!! warning Le module `turtle` de Python
# Pour mieux comprendre comment agit la récursivité, nous allons essayer dans ce notebook de visualiser son effet  sur des figures simples en utilisant le module `turtle` de Python qui permet de dessiner en faisant avancer une "tortue qui tient un stylo".
#
# Avant de commencer l'activité ci-dessous, il est donc conseillé d'apprivoiser turtle en s'aidant par exemple de ce [tutoriel](https://fr.wikibooks.org/wiki/Programmation_Python/Turtle).
# !!!

# %% [markdown]
# ### Exercice 1
# Exécuter la cellule ci-dessous et comprendre comment ce code permet de dessiner un escalier de 5 marches.

# %%
def escalier(nbmarches):
    for i in range(nbmarches):
        left(90)
        forward(50)
        right(90)
        forward(50)


from turtle import *
penup()
goto(-200,-100)
pendown()

escalier(5)

done()

# %% [markdown]
# La fonction `escalier` ci-dessus utilise une **boucle** (algorithme **itératif**) pour dessiner un escalier de plusieurs marches.
#
# On peut utiliser une autre approche appelée **récursive** qui consiste à dire qu'un escalier de n marches est constitué d'une marche suivie d'un escalier de n-1 marches.
#
# On obtient alors le code ci-dessous qui ne contient plus de boucle :

# %%
def escalier_recursif(nbmarches):
    left(90)
    forward(50)
    right(90)
    forward(50)
    escalier_recursif(nbmarches - 1)

from turtle import *
penup()
goto(-200,-100)
pendown()

escalier_recursif(5)

done()

# %% [markdown]
# ---
# ### Exercice 2
# En exécutant la cellule ci-dessus, on obtient une erreur.
# Pourquoi ?

# %% [markdown]
# ---
# ### Exercice 3
# Corriger la fonction récursive précédente en ajoutant une **condition d'arrêt**.

# %% [markdown]
# !!! info Définition :
# Une fonction **récursive** est une fonction qui s'appelle elle-même.
# Elle doit toujours contenir un **cas d'arrêt** aussi appelé **cas de base**.
# !!!

# %% [markdown]
# ---
# ### Exercice 4
# L'étoile ci-dessous est obtenue en faisant 12 fois une ligne droite suivie d'un virage à gauche de 150°.
# <img alt="" src="data:image/jpg;base64,..." />
# Ecrire ci-dessous le code itératif correspondant :

# %% [markdown]
# Ecrire un code récursif permettant d'obtenir le même résultat :

# %% [markdown]
# ---
# ### Exercice 5
# La spirale ci-dessous est telle que :
# - Le côté du grand carré initial mesure 200 pixels
# - Le coin inférieur gauche des carrés est l'origine du repère
# - A chaque étape, les carrés tournent de 20° et le côté diminue de 10%.
# - On interrompt la construction lorsque le côté est inférieur ou égal à 30 pixels
# <img alt="" src="data:image/jpg;base64,..." />
# Ecrire le code récursif correspondant :

# %% [markdown]
# ### Exercice 6
# Le plus grand des carrés ci-dessous à pour côté 300.
# <img alt="" src="data:image/jpg;base64,..." />
# Ecrire le code récursif correspondant :

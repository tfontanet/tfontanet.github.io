# %% [markdown]
# # Les arbres binaires de recherche
# ---
# ## 1. Création de l'arbre
#
# Dans ce document, chaque noeud sera implémenté à l'aide de la classe noeud ci-dessous.

# %%
class Noeud():
    def __init__(self, clé, gauche = None, droit = None):
        self.clé = clé
        self.gauche = gauche
        self.droit = droit
    
    def __repr__(self):
        return f"({self.clé} -> {self.gauche}, {self.droit})".replace("None"," ")

# %% [markdown]
# Dessiner sur une feuille de papier l'arbre ci-dessous :

# %%
A=Noeud(10, Noeud(3, Noeud(2), Noeud(4)), Noeud(20, Noeud(15, None, Noeud(16)), Noeud(22)))

# %% [markdown]
# Cet arbre est-il bien un arbre binaire de recherche ? &nbsp;
# <select>
#     <option>--Sélectionnez la réponse--</option>
#     <option>Oui</option>
#     <option>Non</option>
# </select>

# %% [markdown]
# ### Parcours infixe :
# Compléter ci-dessous d'abord l'assert puis la fonction infixe()

# %%
def infixe(noeud):
    """ renvoie une liste Python contenant les étiquettes dans l'ordre infixe de l'arbre de racine 'noeud' """
    pass

assert infixe(A) == []

# %% [markdown]
# ---
# ## 2. Insertion d'un nouvel élément

# %%
def insère(valeur, noeud):
    """ si 'valeur' n'existe pas encore dans l'ABR de racine 'noeud', on l'insère.
        attention : noeud ne peut être vide """
    pass

insère(21, A)
assert infixe(A) == [2, 3, 4, 10, 15, 16, 20, 21, 22]
insère(7, A)
assert infixe(A) == [2, 3, 4, 7, 10, 15, 16, 20, 21, 22]
insère(6, A)
assert infixe(A) == [2, 3, 4, 6, 7, 10, 15, 16, 20, 21, 22]

# %% [markdown]
# ---
# ## 3. Recherche d'une valeur dans l'arbre

# %%
def recherche(valeur, noeud):
    """ renvoie True ou False selon que 'valeur' a été trouvé ou non dans l'ABR de racine 'noeud' """
    pass

assert recherche(7, A)
assert recherche(15, A)
assert recherche(6, A)
assert recherche(16, A)
assert recherche(10, A)
assert not recherche(1, A)
assert not recherche(5, A)
assert not recherche(11, A)
assert not recherche(30, A)

# %% [markdown]
# ---
# ## 4. Minimum et maximum d'un arbre binaire de recherche

# %%
def minimum(noeud):
    """ renvoie le minimum de toutes les étiquettes de l'ABR de racine 'noeud' """
    pass

assert minimum(A)==2
assert minimum(A.droit)==15

# %%
def maximum(noeud):
    """ renvoie le maximum de toutes les étiquettes de l'ABR de racine 'noeud' """
    pass

assert maximum(A)==22
assert maximum(A.gauche)==7

# %% [markdown]
# ---
# ## 5. Tri d'une liste via un arbre binaire de recherche

# %%
# Création d'une liste aléatoire non triée et sans doublons
from random import shuffle
liste = [i for i in range(20)]
shuffle(liste)

def trie(L):
    """ renvoie une copie triée de la liste 'L' (sans modifier 'L')
        en créant pour cela un ABR et en s'aidant des fonctions ci-dessus """
    pass

assert trie(liste) == sorted(liste)
